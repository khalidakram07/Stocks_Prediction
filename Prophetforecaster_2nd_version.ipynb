# %% [markdown]
# <a href="https://colab.research.google.com/github/khalidakram07/Stocks_Prediction/blob/main/Prophetforecaster_2nd_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
from pandas import datetime

import fbprophet
from fbprophet import Prophet

from fbprophet.plot import add_changepoints_to_plot
from pandas import read_csv

# %%
# data visualization
import matplotlib.pyplot as plt
import seaborn as sns # advanced vizs
# %matplotlib inline

# %%
# !pip install -U -q PyDrive
import pandas as pd

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
downloaded = drive.CreateFile({'id': "1SIEXDaJXlDfACSYeMXj0jy-Sj_lxEkb2"}) 
downloaded.GetContentFile('all_stocks_5yr.csv')  
df = pd.read_csv('all_stocks_5yr.csv')
# Out:
# WARNING:googleapiclient.discovery_cache:file_cache is unavailable when using oauth2client >= 4.0.0 or google-auth
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 33, in <module>
#     from oauth2client.contrib.locked_file import LockedFile
# ModuleNotFoundError: No module named 'oauth2client.contrib.locked_file'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/googleapiclient/discovery_cache/file_cache.py", line 37, in <module>
#     from oauth2client.locked_file import LockedFile
# ModuleNotFoundError: No module named 'oauth2client.locked_file'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/googleapiclient/discovery_cache/__init__.py", line 44, in autodetect
# ...

# %%
# We set the index column and know it has dates))))
df = read_csv('all_stocks_5yr.csv', header=0,index_col=[0], parse_dates=[0])

# %%
df
# Out:
#             close
# date
# 2013-08-02  14.75
# 2013-11-02  14.46
# 2013-12-02  14.27
# 2013-02-13  14.66
# 2013-02-14  13.99
# ...           ...
# 2018-01-02  77.82
# 2018-02-02  76.78
# 2018-05-02  73.83
# 2018-06-02  73.27
# 2018-07-02  73.86
#
# [619040 rows x 1 columns]

# %%
#rename(columns={'column1':'new column name'}) changes the name of the desired column as shown below
df.rename(columns = {'close':'Price'}, inplace = True)
#we can directly print df in colab without using print()
df
# Out:
#             Price
# date
# 2013-08-02  14.75
# 2013-11-02  14.46
# 2013-12-02  14.27
# 2013-02-13  14.66
# 2013-02-14  13.99
# ...           ...
# 2018-01-02  77.82
# 2018-02-02  76.78
# 2018-05-02  73.83
# 2018-06-02  73.27
# 2018-07-02  73.86
#
# [619040 rows x 1 columns]

# %%
#isnull().sum() finds out if theres any empty row in the data frame.
df.isnull().sum()
# Out:
# Price    0
# dtype: int64

# %%
# Color pallete for plotting
color_pal = ["#F8766D", "#D39200", "#93AA00",
             "#00BA38", "#00C19F", "#00B9E3",
             "#619CFF", "#DB72FB"]
         
#df.drop(index=df[df['date'] == '2018-01-01':"2019-01-01"].index, inplace=True)             
df.plot(figsize=(15,5), color=color_pal[0], title='Price')
plt.show()

# %% [markdown]
# # EDA
#
# We will create some time series features to see how the trends are impacted by day of week, hour, time of year, etc.

# %%
def create_features(df, label=None):
    """
    Creates time series features from datetime index.
    """
    df = df.copy()
    df['date'] = df.index
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.weekofyear
    
    X = df[['dayofweek','quarter','month','year',
           'dayofyear','dayofmonth','weekofyear']]
    if label:
        y = df[label]
        return X, y
    return X

X, y = create_features(df, label='Price')

features_and_target = pd.concat([X, y], axis=1)

# %%
#head() give the top 5 values of the dataframe.
features_and_target.head()
# Out:
#             dayofweek  quarter  month  ...  dayofmonth  weekofyear  Price
# date                                   ...
# 2013-08-02          4        3      8  ...           2          31  14.75
# 2013-11-02          5        4     11  ...           2          44  14.46
# 2013-12-02          0        4     12  ...           2          49  14.27
# 2013-02-13          2        1      2  ...          13           7  14.66
# 2013-02-14          3        1      2  ...          14           7  13.99
#
# [5 rows x 8 columns]

# %%
#describe() gives the numerical details of the dataset like mean,min,max,standard deviation and count
features_and_target.describe()
# Out:
#            dayofweek        quarter  ...     weekofyear          Price
# count  619040.000000  619040.000000  ...  619040.000000  619040.000000
# mean        2.410075       2.528051  ...      26.870514      83.043763
# std         1.725672       1.112543  ...      14.923037      97.389748
# min         0.000000       1.000000  ...       1.000000       1.590000
# 25%         1.000000       2.000000  ...      14.000000      40.245000
# 50%         2.000000       3.000000  ...      27.000000      62.620000
# 75%         4.000000       4.000000  ...      40.000000      94.410000
# max         6.000000       4.000000  ...      53.000000    2049.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# We can infer from the following that highest sale has been made on Monday overall with sales upto 1023536329

# %%
#we can check highest price in terms of a month by summing up the values.
highest_sold=features_and_target.groupby(['dayofmonth']).sum()
highest_sold[['Price']]
# Out:
#                    Price
# dayofmonth
# 1           1.663697e+06
# 2           1.744331e+06
# 3           1.633035e+06
# 4           1.618318e+06
# 5           1.725596e+06
# 6           1.733926e+06
# 7           1.516383e+06
# 8           1.786553e+06
# 9           1.576586e+06
# 10          1.722431e+06
# 11          1.764334e+06
# 12          1.865227e+06
# 13          1.747067e+06
# 14          1.657647e+06
# 15          1.653351e+06
# 16          1.631776e+06
# 17          1.722318e+06
# 18          1.684212e+06
# 19          1.710198e+06
# 20          1.675127e+06
# 21          1.710296e+06
# 22          1.762158e+06
# 23          1.679694e+06
# 24          1.718273e+06
# 25          1.532704e+06
# 26          1.630512e+06
# 27          1.687931e+06
# 28          1.678546e+06
# 29          1.607708e+06
# 30          1.561026e+06
# 31          1.006449e+06

# %%
#max() gives the maximum value 
highest_sold[['Price']].max()
# Out:
# Price    9.390004e+06
# dtype: float64

# %% [markdown]
# Plotting the Features to see trends
# Price has strong daily and weekly properties.
# Year also show differences in peaks

# %%
sns.pairplot(features_and_target.dropna(),
             hue='dayofweek',
             x_vars=['dayofweek',
                     'year','weekofyear'],
             y_vars='Price',
             height=6,
             plot_kws={'alpha':1, 'linewidth':1}
            )
plt.suptitle('Price of Stocks week by  Day of Week, Year and Week of Year')
plt.show()

# %%
#Splitting the dataset from 1966
split_date = '2017-01-21'
df_train = df.loc[df.index <= split_date].copy()
df_test = df.loc[df.index > split_date].copy()

# %%
# Plot train and test so you can see where we have split
df_test \
    .rename(columns={'Price': 'TEST SET'}) \
    .join(df_train.rename(columns={'Price': 'TRAINING SET'}),
          how='outer') \
    .plot(figsize=(15,5), title='Overall Rate', )
plt.show()

# %%
# Setup and train model and fit
model = Prophet()
model.fit(df_train.reset_index() \
              .rename(columns={'date':'ds',
                               'Price':'y'}))
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Predict on training set with model
df_test_fcst = model.predict(df=df_test.reset_index() \
                                   .rename(columns={'date':'ds'}))
df_test_fcst.head(5)
# Out:
#           ds      trend  ...  multiplicative_terms_upper       yhat
# 0 2017-01-23  92.490374  ...                         0.0  90.947065
# 1 2017-01-23  92.490374  ...                         0.0  90.947065
# 2 2017-01-23  92.490374  ...                         0.0  90.947065
# 3 2017-01-23  92.490374  ...                         0.0  90.947065
# 4 2017-01-23  92.490374  ...                         0.0  90.947065
#
# [5 rows x 19 columns]

# %%
from sklearn.neural_network import MLPRegressor 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_true=df_test['Price'],
                   y_pred=df_test_fcst['yhat'])
# Out:
# 15980.55069027158

# %%
mean_absolute_error(y_true=df_test['Price'],
                   y_pred=df_test_fcst['yhat'])
# Out:
# 60.6894912576612

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mean_absolute_percentage_error(y_true=df_test['Price'],
                   y_pred=df_test_fcst['yhat'])
# Out:
# 101.70997263513797

# %%
future = model.make_future_dataframe(periods=3)
forecast = model.predict(future)

# %%
from fbprophet.plot import add_changepoints_to_plot
fig = model.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), model, forecast)
from matplotlib import pyplot as plt
plt.show()
fig2 = model.plot_components(forecast)
plt.show()
forecast.tail()
# Out:
#             ds      trend  ...  multiplicative_terms_upper       yhat
# 993 2017-01-19  92.346949  ...                         0.0  91.687219
# 994 2017-01-20  92.382805  ...                         0.0  91.396769
# 995 2017-01-21  92.418662  ...                         0.0  90.936016
# 996 2017-01-22  92.454518  ...                         0.0  91.665864
# 997 2017-01-23  92.490374  ...                         0.0  90.947065
#
# [5 rows x 19 columns]

# %%
type(forecast)
# Out:
# pandas.core.frame.DataFrame
